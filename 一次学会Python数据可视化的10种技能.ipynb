# %%
# 1.比较：比较数据间各类别的关系，或者是它们随着时间的变化趋势，比如折线图；
# 2.联系：查看两个或两个以上变量之间的关系，比如散点图；
# 3.构成：每个部分占整体的百分比，或者是随着时间的百分比变化，比如饼图；
# 4.分布：关注单个变量，或者多个变量的分布情况，比如直方图

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#數據準備
N=1000
x=np.random.randn(N)
y=np.random.randn(N)
#散点图的英文叫做 scatter plot，它将两个变量的值显示在二维坐标中，非常适合展示两个变量之间的关系
#用matplotlib畫散點圖
plt.scatter(x,y,marker='x')
plt.show()
#同Seaborn畫散點圖
df=pd.DataFrame({'x':x,'y':y})
sns.jointplot(x='x',y='y',data=df,kind='scatter')
plt.show()

# %%
#折線圖
#折线图可以用来表示数据随着时间变化的趋势
x=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
y=[5, 3, 6, 20, 17, 16, 19, 30, 32, 35]
# 使用Matplotlib画折线图
plt.plot(x,y)
plt.show()
# 使用Seaborn画折线图
df=pd.DataFrame({'x':x,'y':y})
sns.lineplot(x='x',y='y',data=df)
plt.show()

# %%
#直方图
#直方图可以看到变量的数值分布
a=np.random.randn(100)
s=pd.Series(a)
# 用Matplotlib画直方图
plt.hist(s)
plt.show()
# 用Seaborn画直方图
sns.distplot(s,kde=False) 
plt.show()
sns.distplot(s,kde=True)#kde 代表显示核密度估计，默认是 True
plt.show()

# %%
#條形圖
# 条形图可以帮我们查看类别的特征
x=['Cat1', 'Cat2', 'Cat3', 'Cat4', 'Cat5']
y=[5, 4, 8, 12, 7]
# 用Matplotlib画条形图
plt.bar(x,y)
plt.show()
# 用Seaborn画条形图
sns.barplot(x,y)
plt.show()

# %%
# 箱线图
# 它可以帮我们分析出数据的差异性、离散程度和异常值等
# 由五个数值点组成：最大值 (max)、最小值 (min)、中位数 (median) 和上下四分位数 (Q3, Q1)
# 生成10*4维度数据  0~1之間
data=np.random.normal(size=(10,4))
labels=['A','B','C','D']
# 用Matplotlib画箱线图
plt.boxplot(data,labels=labels)
plt.show()
# 用Seaborn画箱线图
df=pd.DataFrame(data,columns=labels)
sns.boxplot(data=df)
plt.show()

# %%
#饼图
#可以显示每个部分大小与总和之间的比例
nums = [25, 37, 33, 37, 6]
labels = ['High-school','Bachelor','Master','Ph.d', 'Others']# 用Matplotlib画饼图
plt.pie(x=nums,labels=labels)
plt.show()

# %%
# 熱力圖
# 是一种矩阵表示方法，其中矩阵中的元素值用颜色来代表，不同的颜色代表不同大小的值。
# 通过颜色就能直观地知道某个位置上数值的大小

#Seaborn 中自带的数据集 flights，该数据集记录了 1949 年到 1960 年期间，每个月的航班乘客的数量
flights=sns.load_dataset('flights')
data=flights.pivot('year','month','passengers')
sns.heatmap(data)
plt.show()

# %%
from matplotlib.font_manager import FontProperties  
#蜘蛛图
#一种显示一对多关系的方法
#一个变量相对于另一个变量的显著性是清晰可见的
labels=np.array([u"推进","KDA",u"生存",u"团战",u"发育",u"输出"])
stats=[83, 61, 95, 67, 76, 88]
# 画图数据准备，角度、状态值
angles=np.linspace(0,2*np.pi,len(labels),endpoint=False)
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))
# 用Matplotlib画蜘蛛图

#创建一个空白的 figure 对象，这样做的目的相当于画画前先准备一个空白的画板
fig=plt.figure()
#把画板划分成 1 行 1 列
ax=fig.add_subplot(111,polar=True)
#连线
ax.plot(angles,stats,'o-',linewidth=2)
#给图形上色
ax.fill(angles,stats,alpha=0.25)
# 设置中文字体
font=FontProperties(fname=r"C:\Windows\Fonts\simhei.ttf",size=14)
ax.set_thetagrids(angles*180/np.pi,labels,FontProperties=font)
plt.show()

# %%
#二元变量分布
#如果我们想要看两个变量之间的关系，就需要用到二元变量分布
#二元变量分布有多种呈现方式，散点图就是一种二元变量分布
# kind=‘scatter’”代表散点图，
# kind=‘kde’”代表核密度图，
# kind=‘hex’ ”代表 Hexbin 图，它代表的是直方图的二维模拟

#Seaborn 中自带的数据集 tips，这个数据集记录了不同顾客在餐厅的消费账单及小费情况
tips=sns.load_dataset('tips')
print(tips.head(10))

# 用Seaborn画二元变量分布图（散点图，核密度图，Hexbin图）
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
#成对关系
#如果想要探索数据集中的多个成对双变量的分布
#它可以说是探索性分析中的常用函数，可以很快帮我们理解变量对之间的关系
#sns.pairplot() 函数。它会同时展示出 DataFrame 中每对变量的关系

#Seaborn 中自带的 iris 数据集，这个数据集也叫鸢尾花数据集
iris=sns.load_dataset('iris')
# 用Seaborn画成对关系
sns.pairplot(iris)
plt.show()
